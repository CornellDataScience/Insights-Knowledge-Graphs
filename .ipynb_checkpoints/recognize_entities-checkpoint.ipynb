# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

# %%
import scrape
page = scrape.read_page('https://en.wikipedia.org/wiki/Beyonc%C3%A9')
page
# Out:
# reading page: Beyonc%C3%A9
# 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/; born September 4, 1981)[4] is an American singer, songwriter, actress, record producer and dancer. Born and raised in Houston, Texas, Beyoncé performed in various singing and dancing competitions as a child. She rose to fame in the late 1990s as lead singer of the R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the best-selling girl groups in history. Their hiatus saw Beyoncé\'s theatrical film debut in Austin Powers in Goldmember (2002) and the release of her first solo album, Dangerously in Love (2003). The album established her as a solo artist worldwide, debuting at number one on the US Billboard 200 chart and earning five Grammy Awards,[5] and featured the Billboard Hot 100 number one singles "Crazy in Love" and "Baby Boy".Following the break-up of Destiny\'s Child in 2006, she released her second solo album, B\'Day (2006), which contained her fourth number one single, "Irreplaceable", as well as the top ten singles "Déjà Vu", and "Beautiful Liar". Beyoncé also continued her acting career, with starring roles in The Pink Panther (2006), Dreamgirls (2006), and Obsessed (2009). Her marriage to rapper Jay-Z and portrayal of Etta James in Cadillac Records (2008) influenced her third album, I Am... Sasha Fierce (2008), which saw the introduction of her alter-ego Sasha Fierce and earned a record-setting six Grammy Awards in 2010, including Song of the Year for "Single Ladies (Put a Ring on It)".[5] Beyoncé took a hiatus from music in 2010 and took over management of her career; her fourth album 4 (2011) was subsequently mellower in tone, exploring 1970s funk, 1980s pop, and 1990s soul. Her critically acclaimed eponymous album, released in 2013 with no prior announcement, was distinguished from previous releases by its experimental production and exploration of darker themes. Her sixth album, Lemonade (2016), also received widespread critical acclaim, with many referring to it as her most personal and political work to date, and subsequently became the best-selling album of 2016. In 2018, she released Everything Is Love, a collaborative album with husband Jay-Z, as The Carters.Throughout her career, Beyoncé has sold over 100 million records worldwide as a solo artist, and a further 60 million records with Destiny\'s Child,[6] making her one of the best-selling music artists of all time.[7][8] The Recording Industry Association of America recognized Beyoncé as the Top Certified Artist in America during the 2000s decade. In 2009, Billboard named her the Top Radio Songs Artist of the Decade and the Top Female Artist of the 2000s decade.[9][10]Among numerous awards and accolades, Beyoncé has won 22 Grammy Awards[5] and is the most nominated woman in the award\'s history. She is also the most awarded artist at the MTV Video Music Awards, with 24 wins, including the Michael Jackson Video Vanguard Award.[11][12] In 2008, she was and awarded the Legend Award for Outstanding Contribution to the Arts at the World Music Awards. In 2011, Beyoncé was presented with the inaugural Millennium Award at the Billboard Music Awards.[13] In 2014, she became the highest-paid black musician in history and was listed among Time\'s 100 most influential people in the world for a second year in a row.[14] Forbes ranked her as the most powerful female in entertainment on their 2015 and 2017 lists, and in 2016, she occupied the sixth place for Time\'s Person of the Year.[15] In 2016, she was awarded the Fashion Icon lifetime achievement award from the Council of Fashion Designers of America. With the release of Lemonade, Beyoncé became the first and only musical act in Billboard chart history to debut at number one with their first six solo studio albums.[16]Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, a Xerox sales manager.[17] Beyoncé\'s name is a tribute to her  ...

# %%
# paragraph = page[3782: 5188]

sentence = page[3782: 3950]
sentence
# Out:
# 'Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, a Xerox sales manager.'

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(sentence)))
print(ne_tree)
# Out:
# (S
#   (PERSON Beyoncé/NNP)
#   (PERSON Giselle/NNP Knowles/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Houston/NNP)
#   ,/,
#   (GPE Texas/NNP)
#   ,/,
#   to/TO
#   Celestine/VB
#   ``/``
#   (GPE Tina/NNP)
#   ''/''
#   (GPE Knowles/NNP)
#   (/(
#   née/JJ
#   Beyincé/NNP
#   )/)
#   ,/,
#   a/DT
#   hairdresser/NN
#   and/CC
#   salon/NN
#   owner/NN
#   ,/,
#   and/CC
#   (PERSON Mathew/NNP Knowles/NNP)
#   ,/,
#   a/DT
#   Xerox/NNP
#   sales/NNS
#   manager/NN
#   ./.)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent


sent = preprocess(sentence)
sent
# Out:
# [('Beyoncé', 'NNP'),
#  ('Giselle', 'NNP'),
#  ('Knowles', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Houston', 'NNP'),
#  (',', ','),
#  ('Texas', 'NNP'),
#  (',', ','),
#  ('to', 'TO'),
#  ('Celestine', 'VB'),
#  ('``', '``'),
#  ('Tina', 'NNP'),
#  ("''", "''"),
#  ('Knowles', 'NNP'),
#  ('(', '('),
#  ('née', 'JJ'),
#  ('Beyincé', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('a', 'DT'),
#  ('hairdresser', 'NN'),
#  ('and', 'CC'),
#  ('salon', 'NN'),
#  ('owner', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Mathew', 'NNP'),
#  ('Knowles', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Xerox', 'NNP'),
#  ('sales', 'NNS'),
#  ('manager', 'NN'),
#  ('.', '.')]

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   Beyoncé/NNP
#   Giselle/NNP
#   Knowles/NNP
#   was/VBD
#   born/VBN
#   in/IN
#   Houston/NNP
#   ,/,
#   Texas/NNP
#   ,/,
#   to/TO
#   Celestine/VB
#   ``/``
#   Tina/NNP
#   ''/''
#   Knowles/NNP
#   (/(
#   née/JJ
#   Beyincé/NNP
#   )/)
#   ,/,
#   (NP a/DT hairdresser/NN)
#   and/CC
#   (NP salon/NN)
#   (NP owner/NN)
#   ,/,
#   and/CC
#   Mathew/NNP
#   Knowles/NNP
#   ,/,
#   a/DT
#   Xerox/NNP
#   sales/NNS
#   (NP manager/NN)
#   ./.)

# %%
# NPChunker = nltk.RegexpParser(pattern) 
# result = NPChunker.parse(sent)
# result.draw()

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('Beyoncé', 'NNP', 'O'),
#  ('Giselle', 'NNP', 'O'),
#  ('Knowles', 'NNP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('born', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Houston', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Texas', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('to', 'TO', 'O'),
#  ('Celestine', 'VB', 'O'),
#  ('``', '``', 'O'),
#  ('Tina', 'NNP', 'O'),
#  ("''", "''", 'O'),
#  ('Knowles', 'NNP', 'O'),
#  ('(', '(', 'O'),
#  ('née', 'JJ', 'O'),
#  ('Beyincé', 'NNP', 'O'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('hairdresser', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('salon', 'NN', 'B-NP'),
#  ('owner', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('Mathew', 'NNP', 'O'),
#  ('Knowles', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'O'),
#  ('Xerox', 'NNP', 'O'),
#  ('sales', 'NNS', 'O'),
#  ('manager', 'NN', 'B-NP'),
#  ('.', '.', 'O')]

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

doc = nlp(paragraph)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Giselle Knowles', 'PERSON'),
#  ('Houston', 'GPE'),
#  ('Texas', 'GPE'),
#  ('Mathew Knowles', 'PERSON'),
#  ('Xerox', 'GPE'),
#  ('Solange', 'NORP'),
#  ('Solange', 'NORP'),
#  ('first', 'ORDINAL'),
#  ('1', 'CARDINAL'),
#  ('Mathew', 'PERSON'),
#  ('African American', 'NORP'),
#  ('Tina', 'GPE'),
#  ('Louisiana Creole', 'ORG'),
#  ('African', 'NORP'),
#  ('Native American', 'NORP'),
#  ('Acadian', 'NORP'),
#  ('Joseph Broussard.[20', 'PERSON'),
#  ("St. Mary's", 'PERSON'),
#  ('Montessori School', 'PERSON'),
#  ('Houston', 'GPE'),
#  ('Darlette Johnson', 'PERSON'),
#  ('age seven', 'DATE'),
#  ("John Lennon's", 'PERSON'),
#  ('1990', 'DATE'),
#  ('Parker Elementary School', 'ORG'),
#  ('Houston', 'GPE'),
#  ('the High School for the Performing and Visual Arts[26', 'ORG'),
#  ("St. John's", 'GPE'),
#  ('United Methodist Church', 'ORG'),
#  ('two', 'CARDINAL')]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(Beyoncé, 'O', ''),
#  (Giselle, 'B', 'PERSON'),
#  (Knowles, 'I', 'PERSON'),
#  (was, 'O', ''),
#  (born, 'O', ''),
#  (in, 'O', ''),
#  (Houston, 'B', 'GPE'),
#  (,, 'O', ''),
#  (Texas, 'B', 'GPE'),
#  (,, 'O', ''),
#  (to, 'O', ''),
#  (Celestine, 'O', ''),
#  (", 'O', ''),
#  (Tina, 'O', ''),
#  (", 'O', ''),
#  (Knowles, 'O', ''),
#  ((, 'O', ''),
#  (née, 'O', ''),
#  (Beyincé, 'O', ''),
#  (), 'O', ''),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (hairdresser, 'O', ''),
#  (and, 'O', ''),
#  (salon, 'O', ''),
#  (owner, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (Mathew, 'B', 'PERSON'),
#  (Knowles, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (Xerox, 'B', 'GPE'),
#  (sales, 'O', ''),
#  (manager.[17, 'O', ''),
#  (], 'O', ''),
#  (Beyoncé, 'O', ''),
#  ('s, 'O', ''),
#  (name, 'O', ''),
#  (is, 'O', ''),
#  (a, 'O', ''),
#  (tribute, 'O', ''),
#  (to, 'O', ''),
#  (her, 'O', ''),
#  (mother, 'O', ''),
#  ('s, 'O', ''),
#  (maiden, 'O', ''),
#  (name.[18, 'O', ''),
#  (], 'O', ''),
#  (Beyoncé, 'O', ''),
#  ('s, 'O', ''),
#  (younger, 'O', ''),
#  (sister, 'O', ''),
#  (Solange, 'B', 'NORP'),
#  (is, 'O', ''),
#  (also, 'O', ''),
#  (a, 'O', ''),
#  (singer, 'O', ''),
#  (and, 'O', ''),
#  (a, 'O', ''),
#  (former, 'O', ''),
#  (backup, 'O', ''),
#  (dancer, 'O', ''),
#  (for, 'O', ''),
#  (Destiny, 'O', ''),
#  ('s, 'O', ''),
#  (Child, 'O', ''),
#  (., 'O', ''),
#  (Solange, 'B', 'NORP'),
#  (and, 'O', ''),
#  (Beyoncé, 'O', ''),
#  (are, 'O', ''),
#  (the, 'O', ''),
#  (first, 'B', 'ORDINAL'),
#  (sisters, 'O', ''),
#  (to, 'O', ''),
#  (have, 'O', ''),
#  (both, 'O', ''),
#  (had, 'O', ''),
#  (No, 'O', ''),
#  (., 'O', ''),
#  (1, 'B', 'CARDINAL'),
#  (albums.[19, 'O', ''),
#  (], 'O', ''),
#  (Mathew, 'B', 'PERSON'),
#  (is, 'O', ''),
#  (African, 'B', 'NORP'),
#  (American, 'I', 'NORP'),
#  (,, 'O', ''),
#  (while, 'O', ''),
#  (Tina, 'B', 'GPE'),
#  (is, 'O', ''),
#  (of, 'O', ''),
#  (Louisiana, 'B', 'ORG'),
#  (Creole, 'I', 'ORG'),
#  (descent, 'O', ''),
#  ((, 'O', ''),
#  (African, 'B', 'NORP'),
#  (,, 'O', ''),
#  (Native, 'B', 'NORP'),
#  (American, 'I', 'NORP'),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (French).[18][20][21, 'O', ''),
#  (], 'O', ''),
#  (Through, 'O', ''),
#  (her, 'O', ''),
#  (mother, 'O', ''),
#  (,, 'O', ''),
#  (Beyoncé, 'O', ''),
#  (is, 'O', ''),
#  (a, 'O', ''),
#  (descendant, 'O', ''),
#  (of, 'O', ''),
#  (Acadian, 'B', 'NORP'),
#  (leader, 'O', ''),
#  (Joseph, 'B', 'PERSON'),
#  (Broussard.[20, 'I', 'PERSON'),
#  (], 'O', ''),
#  (Beyoncé, 'O', ''),
#  (attended, 'O', ''),
#  (St., 'B', 'PERSON'),
#  (Mary, 'I', 'PERSON'),
#  ('s, 'I', 'PERSON'),
#  (Montessori, 'B', 'PERSON'),
#  (School, 'I', 'PERSON'),
#  (in, 'O', ''),
#  (Houston, 'B', 'GPE'),
#  (,, 'O', ''),
#  (where, 'O', ''),
#  (she, 'O', ''),
#  (enrolled, 'O', ''),
#  (in, 'O', ''),
#  (dance, 'O', ''),
#  (classes, 'O', ''),
#  (., 'O', ''),
#  (Her, 'O', ''),
#  (singing, 'O', ''),
#  (talent, 'O', ''),
#  (was, 'O', ''),
#  (discovered, 'O', ''),
#  (when, 'O', ''),
#  (dance, 'O', ''),
#  (instructor, 'O', ''),
#  (Darlette, 'B', 'PERSON'),
#  (Johnson, 'I', 'PERSON'),
#  (began, 'O', ''),
#  (humming, 'O', ''),
#  (a, 'O', ''),
#  (song, 'O', ''),
#  (and, 'O', ''),
#  (she, 'O', ''),
#  (finished, 'O', ''),
#  (it, 'O', ''),
#  (,, 'O', ''),
#  (able, 'O', ''),
#  (to, 'O', ''),
#  (hit, 'O', ''),
#  (the, 'O', ''),
#  (high, 'O', ''),
#  (-, 'O', ''),
#  (pitched, 'O', ''),
#  (notes.[22, 'O', ''),
#  (], 'O', ''),
#  (Beyoncé, 'O', ''),
#  ('s, 'O', ''),
#  (interest, 'O', ''),
#  (in, 'O', ''),
#  (music, 'O', ''),
#  (and, 'O', ''),
#  (performing, 'O', ''),
#  (continued, 'O', ''),
#  (after, 'O', ''),
#  (winning, 'O', ''),
#  (a, 'O', ''),
#  (school, 'O', ''),
#  (talent, 'O', ''),
#  (show, 'O', ''),
#  (at, 'O', ''),
#  (age, 'B', 'DATE'),
#  (seven, 'I', 'DATE'),
#  (,, 'O', ''),
#  (singing, 'O', ''),
#  (John, 'B', 'PERSON'),
#  (Lennon, 'I', 'PERSON'),
#  ('s, 'I', 'PERSON'),
#  (", 'O', ''),
#  (Imagine, 'O', ''),
#  (", 'O', ''),
#  (to, 'O', ''),
#  (beat, 'O', ''),
#  (15/16-year, 'O', ''),
#  (-, 'O', ''),
#  (olds.[23][24, 'O', ''),
#  (], 'O', ''),
#  (In, 'O', ''),
#  (fall, 'O', ''),
#  (of, 'O', ''),
#  (1990, 'B', 'DATE'),
#  (,, 'O', ''),
#  (Beyoncé, 'O', ''),
#  (enrolled, 'O', ''),
#  (in, 'O', ''),
#  (Parker, 'B', 'ORG'),
#  (Elementary, 'I', 'ORG'),
#  (School, 'I', 'ORG'),
#  (,, 'O', ''),
#  (a, 'O', ''),
#  (music, 'O', ''),
#  (magnet, 'O', ''),
#  (school, 'O', ''),
#  (in, 'O', ''),
#  (Houston, 'B', 'GPE'),
#  (,, 'O', ''),
#  (where, 'O', ''),
#  (she, 'O', ''),
#  (would, 'O', ''),
#  (perform, 'O', ''),
#  (with, 'O', ''),
#  (the, 'O', ''),
#  (school, 'O', ''),
#  ('s, 'O', ''),
#  (choir.[25, 'O', ''),
#  (], 'O', ''),
#  (She, 'O', ''),
#  (also, 'O', ''),
#  (attended, 'O', ''),
#  (the, 'B', 'ORG'),
#  (High, 'I', 'ORG'),
#  (School, 'I', 'ORG'),
#  (for, 'I', 'ORG'),
#  (the, 'I', 'ORG'),
#  (Performing, 'I', 'ORG'),
#  (and, 'I', 'ORG'),
#  (Visual, 'I', 'ORG'),
#  (Arts[26, 'I', 'ORG'),
#  (], 'O', ''),
#  (and, 'O', ''),
#  (later, 'O', ''),
#  (Alief, 'O', ''),
#  (Elsik, 'O', ''),
#  (High, 'O', ''),
#  (School.[18][27, 'O', ''),
#  (], 'O', ''),
#  (Beyoncé, 'O', ''),
#  (was, 'O', ''),
#  (also, 'O', ''),
#  (a, 'O', ''),
#  (member, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (choir, 'O', ''),
#  (at, 'O', ''),
#  (St., 'B', 'GPE'),
#  (John, 'I', 'GPE'),
#  ('s, 'I', 'GPE'),
#  (United, 'B', 'ORG'),
#  (Methodist, 'I', 'ORG'),
#  (Church, 'I', 'ORG'),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (soloist, 'O', ''),
#  (for, 'O', ''),
#  (two, 'B', 'CARDINAL'),
#  (years.[28, 'O', ''),
#  (], 'O', '')]

# %%
# Document-level NER
article = nlp(page)
len(article.ents)
# Out:
# 1629

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 189,
#          'DATE': 298,
#          'EVENT': 28,
#          'FAC': 15,
#          'GPE': 132,
#          'LANGUAGE': 3,
#          'LAW': 5,
#          'LOC': 13,
#          'MONEY': 31,
#          'NORP': 46,
#          'ORDINAL': 99,
#          'ORG': 283,
#          'PERCENT': 3,
#          'PERSON': 324,
#          'PRODUCT': 36,
#          'QUANTITY': 3,
#          'TIME': 9,
#          'WORK_OF_ART': 112})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('first', 38), ('Jay-Z', 24), ('second', 18)]

# %%
sentences = [x for x in article.sents]
print(sentences[19])
# Out:
# In 2014, she became the highest-paid black musician in history and was listed among Time's 100 most influential people in the world for a second year in a row.[14] Forbes ranked her as the most powerful female in entertainment on their 2015 and 2017 lists, and in 2016, she occupied the sixth place for Time's Person of the Year.[15]

# %%
displacy.render(nlp(str(sentences[19])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , she became the highest-paid black musician in history and was listed among
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  most influential people in the world for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     a second year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in a row.[14]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Forbes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ranked her as the most powerful female in entertainment on their
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  lists, and in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , she occupied the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     sixth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  place for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's Person of the Year.[15]</div>

# %%
displacy.render(nlp(str(sentences[19])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="557-0" class="displacy" width="7490" height="857.0" style="max-width: none; height: 857.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">2014,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">became</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">highest-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">paid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">black</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">musician</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">history</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">listed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">among</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">100</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">influential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">world</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">second</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">year</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">row.[14]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="767.0">
#     <tspan clas

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[19])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('In', 'ADP', 'in'),
#  ('2014', 'NUM', '2014'),
#  ('highest', 'ADV', 'highest'),
#  ('paid', 'VERB', 'pay'),
#  ('black', 'ADJ', 'black'),
#  ('musician', 'NOUN', 'musician'),
#  ('history', 'NOUN', 'history'),
#  ('listed', 'VERB', 'list'),
#  ('Time', 'PROPN', 'time'),
#  ("'s", 'PART', "'s"),
#  ('100', 'NUM', '100'),
#  ('influential', 'ADJ', 'influential'),
#  ('people', 'NOUN', 'people'),
#  ('world', 'NOUN', 'world'),
#  ('second', 'ADJ', 'second'),
#  ('year', 'NOUN', 'year'),
#  ('row.[14', 'NOUN', 'row.[14'),
#  ('Forbes', 'PROPN', 'forbes'),
#  ('ranked', 'VERB', 'rank'),
#  ('powerful', 'ADJ', 'powerful'),
#  ('female', 'NOUN', 'female'),
#  ('entertainment', 'NOUN', 'entertainment'),
#  ('2015', 'NUM', '2015'),
#  ('2017', 'NUM', '2017'),
#  ('lists', 'NOUN', 'list'),
#  ('2016', 'NUM', '2016'),
#  ('occupied', 'VERB', 'occupy'),
#  ('sixth', 'ADJ', 'sixth'),
#  ('place', 'NOUN', 'place'),
#  ('Time', 'PROPN', 'time'),
#  ("'s", 'PART', "'s"),
#  ('Person', 'PROPN', 'person'),
#  ('Year.[15', 'PROPN', 'year.[15')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[19])).ents])
# Out:
# {'100': 'CARDINAL',
#  '2014': 'DATE',
#  '2015': 'DATE',
#  '2016': 'DATE',
#  '2017': 'DATE',
#  'Forbes': 'PERSON',
#  'Time': 'ORG',
#  'a second year': 'DATE',
#  'sixth': 'ORDINAL'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[19]])
# Out:
# [(In, 'O', ''), (2014, 'B', 'DATE'), (,, 'O', ''), (she, 'O', ''), (became, 'O', ''), (the, 'O', ''), (highest, 'O', ''), (-, 'O', ''), (paid, 'O', ''), (black, 'O', ''), (musician, 'O', ''), (in, 'O', ''), (history, 'O', ''), (and, 'O', ''), (was, 'O', ''), (listed, 'O', ''), (among, 'O', ''), (Time, 'B', 'ORG'), ('s, 'O', ''), (100, 'B', 'CARDINAL'), (most, 'O', ''), (influential, 'O', ''), (people, 'O', ''), (in, 'O', ''), (the, 'O', ''), (world, 'O', ''), (for, 'O', ''), (a, 'B', 'DATE'), (second, 'I', 'DATE'), (year, 'I', 'DATE'), (in, 'O', ''), (a, 'O', ''), (row.[14, 'O', ''), (], 'O', ''), (Forbes, 'B', 'PERSON'), (ranked, 'O', ''), (her, 'O', ''), (as, 'O', ''), (the, 'O', ''), (most, 'O', ''), (powerful, 'O', ''), (female, 'O', ''), (in, 'O', ''), (entertainment, 'O', ''), (on, 'O', ''), (their, 'O', ''), (2015, 'B', 'DATE'), (and, 'O', ''), (2017, 'B', 'DATE'), (lists, 'O', ''), (,, 'O', ''), (and, 'O', ''), (in, 'O', ''), (2016, 'B', 'DATE'), (,, 'O', ''), (she, 'O', ''), (occupied, 'O', ''), (the, 'O', ''), (sixth, 'B', 'ORDINAL'), (place, 'O', ''), (for, 'O', ''), (Time, 'B', 'ORG'), ('s, 'O', ''), (Person, 'O', ''), (of, 'O', ''), (the, 'O', ''), (Year.[15, 'O', ''), (], 'O', '')]
